# %% [markdown]
# # INTRODUCTION TO PYTHON
#
# - after we met
# - when we separated
# ![Red.jfif](attachment:Red.jfif)

# %%
b= (1,2,3,4)
type(b)
# Out:
# tuple

# %%
s= "10"
type(s)
# Out:
# str

# %%
a= 2.3
type(a)
# Out:
# float

# %%
c= 3+5j
type(c)
# Out:
# complex

# %%
a= 5
type(a)
# Out:
# int

# %%
a= 10
b= 30
print(a<b)
# Out:
# True

# %%
aman123=65
type(aman123)
# Out:
# int

# %%
123aman=34
type(123aman)
# Out:
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_7692/3521260979.py", line 1
#     123aman=34
#        ^
# SyntaxError: invalid syntax

# %%
am123ad=56
type(am123ad)
# Out:
# int

# %%
anam@=23
type(aman@)
# Out:
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_7284/456207118.py", line 2
#     type(aman@)
#               ^
# SyntaxError: invalid syntax

# %%
aman@12=45
type(aman@12)
# Out:
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_7692/4088342328.py", line 1
#     aman@12=45
#     ^
# SyntaxError: cannot assign to operator

# %%
_aman=23
type(_aman)
# Out:
# int

# %% [markdown]
# _123=124
# type(_123)

# %%
True=10
# Out:
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_3484/2941772833.py", line 1
#     True=10
#     ^
# SyntaxError: cannot assign to True

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a=10
float(a)
# Out:
# 10.0

# %%
a
# Out:
# 10

# %%
a= 10.0
a= str(a)

# %%
a
# Out:
# '10.0'

# %%
a= int(a)

# %%
a
# Out:
# '10.0'

# %%
s= 123
s= int(str(float(s)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_752/2447745948.py in <module>
#       1 s= 123
# ----> 2 s= int(str(float(s)))
#
# ValueError: invalid literal for int() with base 10: '123.0'

# %%
s
# Out:
# '123.0'

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16172/2167009006.py in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a= 23
a= float(str(float(a)))

# %%
a
# Out:
# 23.0

# %%
a='23'
a=float(a)

# %%
a
# Out:
# 23.0
